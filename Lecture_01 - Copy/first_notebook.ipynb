# %%
# <span style="color:darkblue"> This is my first Jupyter notebook

# %% [markdown]
# # <span style="color:darkblue"> This is my first Jupyter notebook

# %%
print("Hello my name is Ethan Elbogen")
# Out:
# Hello my name is Ethan Elbogen
